# %% [markdown]
# <a href="https://colab.research.google.com/github/kimjonghuyn/2026-programming/blob/main/%EA%B9%80%EC%A2%85%ED%98%84_Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello wouid!")
# Out:
# hello wouid!
