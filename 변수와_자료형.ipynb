# %% [markdown]
# <a href="https://colab.research.google.com/github/kimjonghuyn/2026-programming/blob/main/%EB%B3%80%EC%88%98%EC%99%80_%EC%9E%90%EB%A3%8C%ED%98%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#변수 할당 및 자료형 확인
a = 100
print(a)
print(type(a))
#변수선언부
age = 18
print(age)
#변수값 대입부
age = 15
age = 16
print(age)
# Out:
# 100
# <class 'int'>
# 18
# 16

# %%
name = '짱구'
height = 170
age = 16
hobby = '영화감상'
print(name, '키는', height, '나이는', age, '취미는', hobby, '입니다.')
name = '코난'
height = 180.5
age = 14
hobby = '프로그래밍'
print(name, '키는', height, '나이는', age, '취미는', hobby, '입니다.')
# Out:
# 짱구 키는 170 나이는 16 취미는 영화감상 입니다.
# 코난 키는 180.5 나이는 14 취미는 프로그래밍 입니다.

# %%
name = input("이름을 입력하세요")
height = input("키를 입력하세요")
age = input("나이를 입력하세요")
hobby = input("취미를 입력하세요")
print(name, '키는', height, '나이는', age, '취미는', hobby, '입니다.')
# Out:
# 이름을 입력하세요13
# 키를 입력하세요11
# 나이를 입력하세요11
# 취미를 입력하세요11
# 13 키는 11 나이는 11 취미는 11 입니다.

# %%
#split()함수활용
#기본값 = 공백
#구분자 지정가능
x, y = input().split("-")
print(f"{x}")
print(f"{y}")
# Out:
# 10-20
# 10
# 20

# %% [markdown]
# #변수명 작성규칙
# 첫번째 문자는 영문자, 한글 또는 밑줄( _ )로 시작해야 한다.
#
#
# 나머지문자는 영문자, 한글, 밑줄( _ ) , 숫자이어야 한다.
#
#
# if, for와 같은 예약어(특정한 기능으로 사용되도록 미리 약속된 단어)는 사용할 수 없다.
#
#
# 공백과 하이픈(-)은 사용할 수 없다.
#
#
# 영문자 대소문자를 구별한다.
#
#
# 저장된 데이터를 알 수 있도록 의미 있는 이름을 사용하는 것이 좋다.
#
#
# 여러단어로 구성된 변수명을 사용하는 경우에는 각 단어를 밑줄( _ ) 로 연결하거나 이어지는 단어를 대문자로 시작하여 가독성을 높이는 것이 좋다(예: sum_result, my_age, sumResult, myAge).

# %%
#변수명 작성규칙
a = 30

나이 = 20 #나이를 저장하는 변수

age = 13
# Out:
# 3
# 4

# %%
# 불 자료형
참 = False
거짓 = True
print(참, type(참))
print(거짓, type(거짓))
print(100 == 20)
print(10 > 5)

# %%
#문자열 자료형

a= '100'
b= 'python'

#문자열 연산

print(a+b) #문자열과 문자열을 연결
print(a*10) #특정 횟수만큼 반복
print(a < b) #문자의 길이 비교
print('1' in a) #특정 문자열 포함 하는지
print('1' not in a) #특정 문자열 포함하지 않는지
# Out:
# 100python
# 100100100100100100100100100100
# True
# True
# False

# %%
#문자열 인덱싱과 슬라이싱
a = "hello"
print(f"첫번째 문자 = {a[0]}")
print(f"마지막 문자 = {a[4]}")
print(f"마지막 문자 = {a[-1]}")
# Out:
# 첫번째 문자 = h
# 마지막 문자 = o
# 마지막 문자 = o
